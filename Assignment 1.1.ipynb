# %%
n=int(input())
for i in range(1,n):
    if i%15 == 0:
        print("your-name")
    elif i%3== 0:
        print("3n")
    elif i%5== 0:
        print("5n")
    else:
        print(i)
# Out:
# 20
# 1
# 2
# 3n
# 4
# 5n
# 3n
# 7
# 8
# 3n
# 5n
# 11
# 3n
# 13
# 14
# your-name
# 16
# 17
# 3n
# 19
